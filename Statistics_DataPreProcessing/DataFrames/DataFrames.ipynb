# %%
import pandas as pd
df = pd.read_csv('FL_insurance_sample.csv',index_col='policyID')

# %%
#
df.head(-10)
# Out:
#          statecode           county  eq_site_limit  hu_site_limit  \
# policyID
# 119736          FL      CLAY COUNTY       498960.0      498960.00
# 448094          FL      CLAY COUNTY      1322376.3     1322376.30
# 206893          FL      CLAY COUNTY       190724.4      190724.40
# 333743          FL      CLAY COUNTY            0.0       79520.76
# 172534          FL      CLAY COUNTY            0.0      254281.50
# 785275          FL      CLAY COUNTY            0.0      515035.62
# 995932          FL      CLAY COUNTY            0.0    19260000.00
# 223488          FL      CLAY COUNTY       328500.0      328500.00
# 433512          FL      CLAY COUNTY       315000.0      315000.00
# 142071          FL      CLAY COUNTY       705600.0      705600.00
# 253816          FL      CLAY COUNTY       831498.3      831498.30
# 894922          FL      CLAY COUNTY            0.0       24059.09
# 422834          FL      CLAY COUNTY            0.0       48115.94
# ...
